# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
pip install pycryptodome
# Out:
# Collecting pycryptodome
#   Downloading https://files.pythonhosted.org/packages/ad/16/9627ab0493894a11c68e46000dbcc82f578c8ff06bc2980dcd016aea9bd3/pycryptodome-3.10.1-cp35-abi3-manylinux2010_x86_64.whl (1.9MB)
#      |████████████████████████████████| 1.9MB 32.6MB/s
# Installing collected packages: pycryptodome
# Successfully installed pycryptodome-3.10.1

# %%
from Crypto.PublicKey import RSA
from Crypto.Cipher import PKCS1_OAEP
import binascii

keyPair = RSA.generate(3072)

pubKey = keyPair.publickey()
print(f"Public key:  (n={hex(pubKey.n)}, e={hex(pubKey.e)})")
pubKeyPEM = pubKey.exportKey()
print(pubKeyPEM.decode('ascii'))

print(f"Private key: (n={hex(pubKey.n)}, d={hex(keyPair.d)})")
privKeyPEM = keyPair.exportKey()
print(privKeyPEM.decode('ascii'))
# Out:
# Public key:  (n=..., e=0x10001)
# -----BEGIN PUBLIC KEY-----
# MIIBojANBgkqhkiG9w0BAQEFAAOCAY8AMIIBigKCAYEAxfnJ0oe1pnu4dhO5+3oh
# lxxzKMY8DCsZxXj9PjqA1Db9yXgbLMdrdMvNXExTwbfjVBBaO6VDtHtm9RZF/LLp
# riiSHGA1Fxgth/DapW/KLnZSSYLfV7ELonh4TqhTSa5J+rgygh1/zx9wAiBOBHj6
# uP5f0Nn/Ns4GeAYMflrDggtuWWLQKAemDYPQNwAsVmDKX87PE38gv1R81wKk+1tR
# UkdBuMIRg+vVwvTEUbS2hXscfajgkNvUeiIV4ewlG6ZUYAOtG7bf3aO0vzUGc3X6
# MoLmKEjDcsOSeA5kXeqpxEF7/m9oAQbQYRr8MuBo+UiKQEZuGoeG5AxZ664pDzAq
# g9b5XQATsmb+VYcQM5SLK6IvPIp45f0RzASoX93ecmfmGjZ/X4hQJeKqEWdd31Lk
# OHnlD49ANX6fo/AI+qBWcgFqg9mEmb45vhH8VBrIgsgu3wSQms7IOm2roHEE046K
# CQqXfn8R8rK+c21QWx/rNlAi9IT1cCO74shqD309FNHXAgMBAAE=
# -----END PUBLIC KEY-----
# Private key: (n=..., d=...)
# -----BEGIN RSA PRIVATE KEY-----
# MIIG4wIBAAKCAYEAxfnJ0oe1pnu4dhO5+3ohlxxzKMY8DCsZxXj9PjqA1Db9yXgb
# LMdrdMvNXExTwbfjVBBaO6VDtHtm9RZF/LLpriiSHGA1Fxgth/DapW/KLnZSSYLf
# V7ELonh4TqhTSa5J+rgygh1/zx9wAiBOBHj6uP5f0Nn/Ns4GeAYMflrDggtuWWLQ
# KAemDYPQNwAsVmDKX87PE38gv1R81wKk+1tRUkdBuMIRg+vVwvTEUbS2hXscfajg
# kNvUeiIV4ewlG6ZUYAOtG7bf3aO0vzUGc3X6MoLmKEjDcsOSeA5kXeqpxEF7/m9o
# AQbQYRr8MuBo+UiKQEZuGoeG5AxZ664pDzAqg9b5XQATsmb+VYcQM5SLK6IvPIp4
# 5f0RzASoX93ecmfmGjZ/X4hQJeKqEWdd31LkOHnlD49ANX6fo/AI+qBWcgFqg9mE
# mb45vhH8VBrIgsgu3wSQms7IOm2roHEE046KCQqXfn8R8rK+c21QWx/rNlAi9IT1
# cCO74shqD309FNHXAgMBAAECggGADxD86oA4c0SMG7RRnZFEWCcqnmpDrJtlGTGl
# eCRkpIHQ25G/468Dfv55kPIgF6iCbOXXsB1aIzSW98Trq5kEDqR4xh8OO0U0Rdmv
# EhMJXHLVvVFv5NEM9R7c7QODXyKb77Av69YJ4X3ffNHvjgiU8BovuYm1kfqo5F51
# efI3WcC786KA++LlILcs09q4BRTVoefvu2ib2eO4onZJjvV6oVvZ5REj2xnKCU2u
# WRd7InplhyygdnW8XFUWvDxH8Kw+MlC9Ku2CVi+CiKksq+MOMywab+mbaBO6Nqyi
# V0wlOhu4n2xIVMtAsnLw326643gmEsCemEBfRQ3A/FAHmRPP/xTmBrb1KZDXgvAb
# 1S+O5+zAChUMIXmAWDJ40hQLGoYqOcs0z6ZH5CwJ4QOuxK5Q/vN4Jlh3E22UVcrJ
# XIAcphZKMKcFh3rshtmuzdcGlS6FB7q+ZV+9YVlLDk/mf6q/Pf0VqFqzcd1XAgJZ
# O1Gexfd3Z97pP1Q6zXhCXVR0ICN9AoHBANzM5Rjrc9BIC2fBhu/K7RnVttYVJO+3
# 6VO9aZEw5L9luFlzjNQlI6vMZGhEu1+WAcyGu9rrlRnPXjrSGk/mxC6HWYtIKxdt
# hp4O3RuX3t2DiE00Wn16XK+JZeZj3zw1FIc/j9ZfPuJ6/cQY/XLfzpFswRhqsCwF
# 3gce0tz3+g1kzJ/mUX3K/x3nmkOmdw9JByFW+67JPe08Ylf8jxhPZ3Cq43ZcFIKm
# kjNyszk+cpnXj11ZpORpKrvShdIkN+zPGwKBwQDliWUk3heORung0hrUpxGaAiCq
# gn6Tg9tSAaAUlgSnL9qUsSJ9+dnKMMfDpdmuYXvA4qihi5hn0KCHQdikRFcRiZGE
# uguIeGydiuUVz6dGnidKPAHk7HP9uDYM7JP7v1e/mRolS+RAM1dZ070hLBajxKJR
# zvN3JwCf6pXapmCKV1xSS4a/o3bljPoSaeB3hU3DLommO9u0JfKVhtHJCpRgxLxM
# fNMqWtB7jYdcTMs+z2epbQJB/y+rYmh7hAKIp/UCgcBwrDIgVE5mM812JeCYzyHM
# 9Cz39BREK8JqVBbh22RvcxXut7NespEQYx29w40mSuMiHoMQRPVyFUrNk1eP/H+S
# Csmb9LjgnKh8UbNtGEPHIA7W7udabq2Lef7A4agSDjgqiDn7N+FcK00B24rCKwk7
# Vpb2wcKixF+3nHgYAIbefNiapCpjmcoz1XL4IKNS7n4v+jY2zETIoe7BXYUb77Em
# Yl3ukTB6N0wV6usgRAixDrn+9fbaA/ylmdlmEctkEY8CgcAWmr9BMDX1pvolT8ug
# oYtUNV1uLUe100hn/Qz8ugFfTZEjD4asDUzrYn5pwA195M/BIREmR48Mujj02QEy
# vCAu8/NGtOOp3uIjaahBy59Xjv+jieFN4BNUKy33e9ze7+r+TV+LyLuDrwqtJ/L6
# L1NTcWvizpSfaVHgbcOwMq5TMWNAH3v3p2twE8AUzCR04MXVsOGRY1exmAMZwpsq
# R0ZxeS5qAejxxNu/LyLjbhSd7OLyhm+wfCb/o8NSVp/BQXkCgcEAvwvSJPXAKXBN
# shtb9gRL6b/o/6Od5e4hm3hQiNAvutj52oMa00BNZl53i9lF54y35IHxWflhr+Pu
# xgwHP5OmN8WJeOTp2SjTZpEx/ATViMqw/mAz61bCwOSQguty85fva+2Hrs+U9SYn
# XiE/T26peqx0eI5vnvHZhFSTicwYVHFUrdcJ5msUWSgeBd/4tPSwnBcKjq5cWxO1
# gnacbpQ7NyV2HT5q7w1m7kAr6yaIzaA//8Oo4IyB1WGeFPNVGVKf
# -----END RSA PRIVATE KEY-----

# %%
msg = b'A message for encryption'
encryptor = PKCS1_OAEP.new(pubKey)
encrypted = encryptor.encrypt(msg)
print("Encrypted:", binascii.hexlify(encrypted))
# Out:
# Encrypted: b'...'

# %%
decryptor = PKCS1_OAEP.new(keyPair)
decrypted = decryptor.decrypt(encrypted)
print('Decrypted:', decrypted)
# Out:
# Decrypted: b'A message for encryption'
